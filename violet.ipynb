# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
base = pd.read_csv('Usuarios.csv')
sns.violinplot(x = 'salario', data=base)
plt.show()

# %%
base.shape
# Out:
# (36, 9)
